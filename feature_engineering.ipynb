# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("movies_dataset.csv")

# %%
df
# Out:
#       adult                     backdrop_path                  genre_ids  \
# 0     False  /e4OnHU8HNAhdS6C4Ypk6NA26kPQ.jpg               [28, 35, 80]
# 1     False  /tyjXlexbNZQ0ZT1KEJslQtBirqc.jpg              [12, 53, 878]
# 2     False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  [16, 35, 12, 10751, 9648]
# 3     False  /4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg           [28, 80, 18, 53]
# 4     False  /tNONILTe9OJz574KZWaLze4v6RC.jpg                 [9648, 53]
# ...     ...                               ...                        ...
# 9995  False                               NaN                [10749, 18]
# 9996  False  /dz0p1gSQkqauRsFi0rF32pXDY4w.jpg            [35, 18, 10749]
# 9997  False                               NaN                         []
# 9998  False  /rien0JIthKGopmZjSmWID9gUHCC.jpg                   [99, 35]
# 9999  False                               NaN                   [18, 35]
#
#            id original_language          original_title  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              10000 non-null  bool
#  1   backdrop_path      7023 non-null   object
#  2   genre_ids          10000 non-null  object
#  3   id                 10000 non-null  int64
#  4   original_language  10000 non-null  object
#  5   original_title     10000 non-null  object
#  6   overview           9650 non-null   object
#  7   popularity         10000 non-null  float64
#  8   poster_path        9242 non-null   object
#  9   release_date       9852 non-null   object
#  10  title              10000 non-null  object
#  11  video              10000 non-null  bool
#  12  vote_average       10000 non-null  float64
#  13  vote_count         10000 non-null  int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 957.2+ KB

# %%
df=df.drop(["adult","backdrop_path","original_title","poster_path","video",],axis=1)

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9520 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          9520 non-null   object
#  1   id                 9520 non-null   int64
#  2   original_language  9520 non-null   object
#  3   overview           9520 non-null   object
#  4   popularity         9520 non-null   float64
#  5   release_date       9520 non-null   object
#  6   title              9520 non-null   object
#  7   vote_average       9520 non-null   float64
#  8   vote_count         9520 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 743.8+ KB

# %%
df
# Out:
#                       genre_ids       id original_language  \
# 0                  [28, 35, 80]  1168190                en
# 1                 [12, 53, 878]   840464                en
# 2     [16, 35, 12, 10751, 9648]  1084242                en
# 3              [28, 80, 18, 53]  1419406                zh
# 4                    [9648, 53]  1368166                en
# ...                         ...      ...               ...
# 9995                [10749, 18]   451405                en
# 9996            [35, 18, 10749]   239030                de
# 9997                         []   566723                en
# 9998                   [99, 35]    37299                en
# 9999                   [18, 35]   847371                te
#
#                                                overview  popularity  \
# 0     Estranged half-brothers Jonny and James reunit...    673.3304
# 1     Having found the safety of the Greenland bunke...    624.2323
# ...

# %%
df["original_language"].unique()
# Out:
# array(['en', 'zh', 'hi', 'de', 'te', 'ko', 'ja', 'th', 'fr', 'ta', 'tl',
#        'pt', 'fi', 'es', 'ml', 'id', 'tr', 'it', 'kn', 'no', 'ru', 'ms',
#        'sr', 'ca', 'nl', 'da', 'cn', 'sv', 'lv', 'el', 'hu', 'pl', 'is',
#        'sl', 'cs', 'ro', 'hr', 'bs', 'uk', 'ar', 'bn', 'sh', 'sk', 'eu',
#        'et', 'fa', 'xx', 'pa', 'sq', 'af', 'ne', 'ku', 'yi', 'mr', 'zu',
#        'bg', 'ur', 'he', 'ab', 'mk', 'lt', 'jv', 'az', 'hy', 'cy', 'vi',
#        'mn', 'ga', 'gu', 'as', 'qu', 'xh', 'wo'], dtype=object)
